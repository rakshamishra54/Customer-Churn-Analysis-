# %% [markdown]
# <a href="https://colab.research.google.com/github/rakshamishra54/Customer-Churn-Analysis-/blob/main/customer_churn_modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
telco_data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Telco-Customer-Churn.csv')
# Out:
# Mounted at /content/drive
